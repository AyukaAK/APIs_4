# %% [markdown]
# # WeatherAPI (Weather)
#
# Answer the following questions using [WeatherAPI](http://www.weatherapi.com/). I've added three cells for most questions but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# Be sure to take advantage of both the documentation and the API Explorer!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*
# - *Tip: Remember you only need to import requests once!*

# %% [markdown]
# [Interactive API Explorer](https://www.weatherapi.com/api-explorer.aspx#forecast)
#
# [Documentation](https://www.weatherapi.com/docs/)

# %%
import requests

# %% [markdown]
# ## 1) Make a request to the Weather API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
url_live = "http://api.weatherapi.com/v1/current.json?key=976685a7f4594f9c90b191549221406&q=Reykjavik&aqi=no"

# %%
response = requests.get (url_live)
data = response.json()

# %% [markdown]
# This is a request to the weather API for Reykjavik, Iceland

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
print(data)
# Out:
# {'location': {'name': 'Reykjavik', 'region': 'Gullbringusysla', 'country': 'Iceland', 'lat': 64.15, 'lon': -21.95, 'tz_id': 'Atlantic/Reykjavik', 'localtime_epoch': 1655407060, 'localtime': '2022-06-16 19:17'}, 'current': {'last_updated_epoch': 1655402400, 'last_updated': '2022-06-16 18:00', 'temp_c': 11.0, 'temp_f': 51.8, 'is_day': 0, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 18.6, 'wind_kph': 29.9, 'wind_degree': 140, 'wind_dir': 'SE', 'pressure_mb': 1003.0, 'pressure_in': 29.62, 'precip_mm': 0.1, 'precip_in': 0.0, 'humidity': 58, 'cloud': 75, 'feelslike_c': 8.0, 'feelslike_f': 46.3, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.0, 'gust_mph': 20.8, 'gust_kph': 33.5}}

# %%
print(data['current']['wind_kph'])
# Out:
# 29.9

# %%
print(data['current'].keys())
# Out:
# dict_keys(['last_updated_epoch', 'last_updated', 'temp_c', 'temp_f', 'is_day', 'condition', 'wind_mph', 'wind_kph', 'wind_degree', 'wind_dir', 'pressure_mb', 'pressure_in', 'precip_mm', 'precip_in', 'humidity', 'cloud', 'feelslike_c', 'feelslike_f', 'vis_km', 'vis_miles', 'uv', 'gust_mph', 'gust_kph'])

# %%
print(data['current']['temp_c'])
# Out:
# 11.0

# %%
print(data['current']['feelslike_c'])
# Out:
# 8.0

# %%
print("It feels like", round(data['current']['temp_c']-data['current']['feelslike_c']), "C degree warmer than it actually is")
# Out:
# It feels like 3 C degree warmer than it actually is

# %% [markdown]
# ## 3) What is the API endpoint for moon-related information? For the place you decided on above, how much of the moon will be visible tomorrow?
#
# - *Tip: Check the documentation!*
# - *Tip: If you aren't sure what something means, ask in Slack*

# %%
url_moon = "http://api.weatherapi.com/v1/astronomy.json?key=976685a7f4594f9c90b191549221406&q=Reykjavik&dt=2022-06-16"
response_moon = requests.get(url_moon)
data_moon = response_moon.json()

# %%
print(data_moon)
# Out:
# {'location': {'name': 'Reykjavik', 'region': 'Gullbringusysla', 'country': 'Iceland', 'lat': 64.15, 'lon': -21.95, 'tz_id': 'Atlantic/Reykjavik', 'localtime_epoch': 1655407229, 'localtime': '2022-06-16 19:20'}, 'astronomy': {'astro': {'sunrise': '02:56 AM', 'sunset': '12:00 AM', 'moonrise': '12:00 AM', 'moonset': '12:00 AM', 'moon_phase': 'Full Moon', 'moon_illumination': '86'}}}

# %%
print(data_moon['astronomy']['astro']['moon_phase'])
# Out:
# Full Moon

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?
#
# - *Tip: When you requested moon data, you probably overwrote your variables! If so, you'll need to make a new request.*

# %%
url_today = "http://api.weatherapi.com/v1/forecast.json?key=976685a7f4594f9c90b191549221406&q=Reykjavik&days=1&aqi=no&alerts=no"
response = requests.get(url_today)
data = response.json()
print(data)
# Out:
# {'location': {'name': 'Reykjavik', 'region': 'Gullbringusysla', 'country': 'Iceland', 'lat': 64.15, 'lon': -21.95, 'tz_id': 'Atlantic/Reykjavik', 'localtime_epoch': 1655407194, 'localtime': '2022-06-16 19:19'}, 'current': {'last_updated_epoch': 1655406900, 'last_updated': '2022-06-16 19:15', 'temp_c': 11.0, 'temp_f': 51.8, 'is_day': 0, 'condition': {'text': 'Light rain', 'icon': '//cdn.weatherapi.com/weather/64x64/night/296.png', 'code': 1183}, 'wind_mph': 18.6, 'wind_kph': 29.9, 'wind_degree': 140, 'wind_dir': 'SE', 'pressure_mb': 1003.0, 'pressure_in': 29.62, 'precip_mm': 0.1, 'precip_in': 0.0, 'humidity': 62, 'cloud': 100, 'feelslike_c': 8.0, 'feelslike_f': 46.3, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.0, 'gust_mph': 20.8, 'gust_kph': 33.5}, 'forecast': {'forecastday': [{'date': '2022-06-16', 'date_epoch': 1655337600, 'day': {'maxtemp_c': 11.4, 'maxtemp_f': 52.5, 'mintemp_c': 8.5, 'mintemp_f': 47.3, 'avgtemp_c': 10.0, 'avgtemp_f': 50.0, 'maxwind_mph': 19.5, 'maxwind_kph': 31.3, 'totalprecip_mm': 2.8, 'totalprecip_in': 0.11, 'avgvis_km': 9.9, 'avgvis_miles': 6.0, 'avghumidity': 67.0, 'daily_will_it_rain': 1, 'daily_chance_of_rain': 99, 'daily_will_it_snow': 0, 'daily_chance_of_snow': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'uv': 4.0}, 'astro': {'sunrise': '02:57 AM', 'sunset': 'No sunset', 'moonrise': '12:00 AM', 'moonset': '12:00 AM', 'moon_phase': 'Waxing Gibbous', 'moon_illumination': '78'}, 'hour': [{'time_epoch': 1655337600, 'time': '2022-06-16 00:00', 'temp_c': 8.7, 'temp_f': 47.7, 'is_day': 0, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 17.2, 'wind_kph': 27.7, 'wind_degree': 156, 'wind_dir': 'SSE', 'pressure_mb': 1005.0, 'pressure_in': 29.67, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 70, 'cloud': 53, 'feelslike_c': 5.0, 'feelslike_f': 41.0, 'windchill_c': 5.0, 'windchill_f': 41.0, 'heatindex_c': 8.7, 'heatindex_f': 47.7, 'dewpoint_c': 3.6, 'dewpoint_f': 38.5, 'will_it_rain': 0, 'chance_of_rain': 0, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 23.5, 'gust_kph': 37.8, 'uv': 1.0}, {'time_epoch': 1655341200, 'time': '2022-06-16 01:00', 'temp_c': 8.7, 'temp_f': 47.7, 'is_day': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png', 'code': 1063}, 'wind_mph': 17.4, 'wind_kph': 28.1, 'wind_degree': 156, 'wind_dir': 'SSE', 'pressure_mb': 1005.0, 'pressure_in': 29.67, 'precip_mm': 0.1, 'precip_in': 0.0, 'humidity': 69, 'cloud': 61, 'feelslike_c': 5.0, 'feelslike_f': 41.0, 'windchill_c': 5.0, 'windchill_f': 41.0, 'heatindex_c': 8.7, 'heatindex_f': 47.7, 'dewpoint_c': 3.4, 'dewpoint_f': 38.1, 'will_it_rain': 1, 'chance_of_rain': 98, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 23.7, 'gust_kph': 38.2, 'uv': 1.0}, {'time_epoch': 1655344800, 'time': '2022-06-16 02:00', 'temp_c': 8.6, 'temp_f': 47.5, 'is_day': 0, 'condition': {'text': 'Cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png', 'code': 1006}, 'wind_mph': 17.4, 'wind_kph': 28.1, 'wind_degree': 154, 'wind_dir': 'SSE', 'pressure_mb': 1005.0, 'pressure_in': 29.66, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 69, 'cloud': 83, 'feelslike_c': 4.9, 'feelslike_f': 40.8, 'windchill_c': 4.9, 'windchill_f': 40.8, 'heatindex_c': 8.6, 'heatindex_f': 47.5, 'dewpoint_c': 3.2, 'dewpoint_f': 37.8, 'will_it_rain': 0, 'chance_of_rain': 0, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 24.2, 'gust_kph': 38.9, 'uv': 1.0}, {'time_epoch': 1655348400, 'time': '2022-06-16 03:00', 'temp_c': 8.7, 'temp_f': 47.7, 'is_day': 0, 'condition': {'text': 'Light rain shower', 'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png', 'code': 1240}, 'wind_mph': 17.4, 'wind_kph': 28.1, 'wind_degree': 150, 'wind_dir': 'SSE', 'pressure_mb': 1005.0, 'pres ...

# %% [markdown]
# For the max and min temp for today, you need to have the forecast API (one day)

# %%
print(data['forecast']['forecastday'][0]['day'].keys())
# Out:
# dict_keys(['maxtemp_c', 'maxtemp_f', 'mintemp_c', 'mintemp_f', 'avgtemp_c', 'avgtemp_f', 'maxwind_mph', 'maxwind_kph', 'totalprecip_mm', 'totalprecip_in', 'avgvis_km', 'avgvis_miles', 'avghumidity', 'daily_will_it_rain', 'daily_chance_of_rain', 'daily_will_it_snow', 'daily_chance_of_snow', 'condition', 'uv'])

# %%
temp_dif = data['forecast']['forecastday'][0]['day']['maxtemp_c']-data['forecast']['forecastday'][0]['day']['mintemp_c']
print("Temperatures difference between the high and the low is", round(temp_dif),"C degrees")
# Out:
# Temperatures difference between the high and the low is 3 C degrees

# %% [markdown]
# ## 4.5) How can you avoid the "oh no I don't have the data any more because I made another request" problem in the future?
#
# What variable(s) do you have to rename, and what would you rename them?

# %% [markdown]
# ### You name the url variable with different names

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next three days' worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
url_3days = 'http://api.weatherapi.com/v1/forecast.json?key=976685a7f4594f9c90b191549221406&q=Reykjavik&days=3&aqi=no&alerts=no'
response_3days = requests.get(url_3days)
data_3days = response_3days.json()
print(data_3days)
# Out:
# {'location': {'name': 'Reykjavik', 'region': 'Gullbringusysla', 'country': 'Iceland', 'lat': 64.15, 'lon': -21.95, 'tz_id': 'Atlantic/Reykjavik', 'localtime_epoch': 1655408114, 'localtime': '2022-06-16 19:35'}, 'current': {'last_updated_epoch': 1655407800, 'last_updated': '2022-06-16 19:30', 'temp_c': 11.0, 'temp_f': 51.8, 'is_day': 0, 'condition': {'text': 'Light rain', 'icon': '//cdn.weatherapi.com/weather/64x64/night/296.png', 'code': 1183}, 'wind_mph': 18.6, 'wind_kph': 29.9, 'wind_degree': 140, 'wind_dir': 'SE', 'pressure_mb': 1003.0, 'pressure_in': 29.62, 'precip_mm': 0.1, 'precip_in': 0.0, 'humidity': 62, 'cloud': 100, 'feelslike_c': 8.0, 'feelslike_f': 46.3, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.0, 'gust_mph': 20.8, 'gust_kph': 33.5}, 'forecast': {'forecastday': [{'date': '2022-06-16', 'date_epoch': 1655337600, 'day': {'maxtemp_c': 11.4, 'maxtemp_f': 52.5, 'mintemp_c': 8.5, 'mintemp_f': 47.3, 'avgtemp_c': 10.0, 'avgtemp_f': 50.0, 'maxwind_mph': 19.5, 'maxwind_kph': 31.3, 'totalprecip_mm': 2.8, 'totalprecip_in': 0.11, 'avgvis_km': 9.9, 'avgvis_miles': 6.0, 'avghumidity': 67.0, 'daily_will_it_rain': 1, 'daily_chance_of_rain': 99, 'daily_will_it_snow': 0, 'daily_chance_of_snow': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'uv': 4.0}, 'astro': {'sunrise': '02:57 AM', 'sunset': 'No sunset', 'moonrise': '12:00 AM', 'moonset': '12:00 AM', 'moon_phase': 'Waxing Gibbous', 'moon_illumination': '78'}, 'hour': [{'time_epoch': 1655337600, 'time': '2022-06-16 00:00', 'temp_c': 8.7, 'temp_f': 47.7, 'is_day': 0, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 17.2, 'wind_kph': 27.7, 'wind_degree': 156, 'wind_dir': 'SSE', 'pressure_mb': 1005.0, 'pressure_in': 29.67, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 70, 'cloud': 53, 'feelslike_c': 5.0, 'feelslike_f': 41.0, 'windchill_c': 5.0, 'windchill_f': 41.0, 'heatindex_c': 8.7, 'heatindex_f': 47.7, 'dewpoint_c': 3.6, 'dewpoint_f': 38.5, 'will_it_rain': 0, 'chance_of_rain': 0, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 23.5, 'gust_kph': 37.8, 'uv': 1.0}, {'time_epoch': 1655341200, 'time': '2022-06-16 01:00', 'temp_c': 8.7, 'temp_f': 47.7, 'is_day': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png', 'code': 1063}, 'wind_mph': 17.4, 'wind_kph': 28.1, 'wind_degree': 156, 'wind_dir': 'SSE', 'pressure_mb': 1005.0, 'pressure_in': 29.67, 'precip_mm': 0.1, 'precip_in': 0.0, 'humidity': 69, 'cloud': 61, 'feelslike_c': 5.0, 'feelslike_f': 41.0, 'windchill_c': 5.0, 'windchill_f': 41.0, 'heatindex_c': 8.7, 'heatindex_f': 47.7, 'dewpoint_c': 3.4, 'dewpoint_f': 38.1, 'will_it_rain': 1, 'chance_of_rain': 98, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 23.7, 'gust_kph': 38.2, 'uv': 1.0}, {'time_epoch': 1655344800, 'time': '2022-06-16 02:00', 'temp_c': 8.6, 'temp_f': 47.5, 'is_day': 0, 'condition': {'text': 'Cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png', 'code': 1006}, 'wind_mph': 17.4, 'wind_kph': 28.1, 'wind_degree': 154, 'wind_dir': 'SSE', 'pressure_mb': 1005.0, 'pressure_in': 29.66, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 69, 'cloud': 83, 'feelslike_c': 4.9, 'feelslike_f': 40.8, 'windchill_c': 4.9, 'windchill_f': 40.8, 'heatindex_c': 8.6, 'heatindex_f': 47.5, 'dewpoint_c': 3.2, 'dewpoint_f': 37.8, 'will_it_rain': 0, 'chance_of_rain': 0, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 24.2, 'gust_kph': 38.9, 'uv': 1.0}, {'time_epoch': 1655348400, 'time': '2022-06-16 03:00', 'temp_c': 8.7, 'temp_f': 47.7, 'is_day': 0, 'condition': {'text': 'Light rain shower', 'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png', 'code': 1240}, 'wind_mph': 17.4, 'wind_kph': 28.1, 'wind_degree': 150, 'wind_dir': 'SSE', 'pressure_mb': 1005.0, 'pres ...

# %%
print(data_3days['forecast']['forecastday'][0]['day'])
# Out:
# {'maxtemp_c': 11.4, 'maxtemp_f': 52.5, 'mintemp_c': 8.5, 'mintemp_f': 47.3, 'avgtemp_c': 10.0, 'avgtemp_f': 50.0, 'maxwind_mph': 19.5, 'maxwind_kph': 31.3, 'totalprecip_mm': 2.8, 'totalprecip_in': 0.11, 'avgvis_km': 9.9, 'avgvis_miles': 6.0, 'avghumidity': 67.0, 'daily_will_it_rain': 1, 'daily_chance_of_rain': 99, 'daily_will_it_snow': 0, 'daily_chance_of_snow': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'uv': 4.0}

# %%
print(data_3days['forecast']['forecastday'][0]['day']['maxtemp_c'])
# Out:
# 11.4

# %%
print(data_3days['forecast']['forecastday'][0]['date'])
# Out:
# 2022-06-16

# %%
for max_temp in data_3days['forecast']['forecastday']:
    if max_temp['day']['maxtemp_c'] < 15:
        print("On", max_temp['date'], "The highest temperature is", max_temp['day']['maxtemp_c'], "C degrees and it's cold")

print ("It is always below 15C degrees and cold in Reykjavik, Iceland, because it's in the Arctic!!")
# Out:
# On 2022-06-16 The highest temperature is 11.4 C degrees and it's cold
# On 2022-06-17 The highest temperature is 11.7 C degrees and it's cold
# On 2022-06-18 The highest temperature is 11.1 C degrees and it's cold
# It is always below 15C degrees and cold in Reykjavik, Iceland, because it's in the Arctic!!

# %% [markdown]
# ## 5b) The question above used to be an entire week, but not any more. Try to re-use the code above to print out seven days.
#
# What happens? Can you figure out why it doesn't work?
#
# * *Tip: it has to do with the reason you're using an API key - maybe take a look at the "Air Quality Data" introduction for a hint? If you can't figure it out right now, no worries.*

# %%
url_7days = 'http://api.weatherapi.com/v1/forecast.json?key=976685a7f4594f9c90b191549221406&q=Reykjavik&days=7&aqi=no&alerts=no'
response_7days = requests.get(url_7days)
data_7days = response_7days.json()
print(data_7days)
# Out:
# {'location': {'name': 'Reykjavik', 'region': 'Gullbringusysla', 'country': 'Iceland', 'lat': 64.15, 'lon': -21.95, 'tz_id': 'Atlantic/Reykjavik', 'localtime_epoch': 1655409709, 'localtime': '2022-06-16 20:01'}, 'current': {'last_updated_epoch': 1655406000, 'last_updated': '2022-06-16 19:00', 'temp_c': 9.0, 'temp_f': 48.2, 'is_day': 0, 'condition': {'text': 'Overcast', 'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png', 'code': 1009}, 'wind_mph': 20.6, 'wind_kph': 33.1, 'wind_degree': 130, 'wind_dir': 'SE', 'pressure_mb': 1002.0, 'pressure_in': 29.59, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 76, 'cloud': 75, 'feelslike_c': 5.4, 'feelslike_f': 41.7, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.0, 'gust_mph': 20.4, 'gust_kph': 32.8}, 'forecast': {'forecastday': [{'date': '2022-06-16', 'date_epoch': 1655337600, 'day': {'maxtemp_c': 11.4, 'maxtemp_f': 52.5, 'mintemp_c': 8.5, 'mintemp_f': 47.3, 'avgtemp_c': 10.0, 'avgtemp_f': 50.0, 'maxwind_mph': 19.5, 'maxwind_kph': 31.3, 'totalprecip_mm': 2.8, 'totalprecip_in': 0.11, 'avgvis_km': 9.9, 'avgvis_miles': 6.0, 'avghumidity': 67.0, 'daily_will_it_rain': 1, 'daily_chance_of_rain': 99, 'daily_will_it_snow': 0, 'daily_chance_of_snow': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'uv': 4.0}, 'astro': {'sunrise': '02:57 AM', 'sunset': 'No sunset', 'moonrise': '12:00 AM', 'moonset': '12:00 AM', 'moon_phase': 'Waxing Gibbous', 'moon_illumination': '78'}, 'hour': [{'time_epoch': 1655337600, 'time': '2022-06-16 00:00', 'temp_c': 8.7, 'temp_f': 47.7, 'is_day': 0, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 17.2, 'wind_kph': 27.7, 'wind_degree': 156, 'wind_dir': 'SSE', 'pressure_mb': 1005.0, 'pressure_in': 29.67, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 70, 'cloud': 53, 'feelslike_c': 5.0, 'feelslike_f': 41.0, 'windchill_c': 5.0, 'windchill_f': 41.0, 'heatindex_c': 8.7, 'heatindex_f': 47.7, 'dewpoint_c': 3.6, 'dewpoint_f': 38.5, 'will_it_rain': 0, 'chance_of_rain': 0, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 23.5, 'gust_kph': 37.8, 'uv': 1.0}, {'time_epoch': 1655341200, 'time': '2022-06-16 01:00', 'temp_c': 8.7, 'temp_f': 47.7, 'is_day': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png', 'code': 1063}, 'wind_mph': 17.4, 'wind_kph': 28.1, 'wind_degree': 156, 'wind_dir': 'SSE', 'pressure_mb': 1005.0, 'pressure_in': 29.67, 'precip_mm': 0.1, 'precip_in': 0.0, 'humidity': 69, 'cloud': 61, 'feelslike_c': 5.0, 'feelslike_f': 41.0, 'windchill_c': 5.0, 'windchill_f': 41.0, 'heatindex_c': 8.7, 'heatindex_f': 47.7, 'dewpoint_c': 3.4, 'dewpoint_f': 38.1, 'will_it_rain': 1, 'chance_of_rain': 98, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 23.7, 'gust_kph': 38.2, 'uv': 1.0}, {'time_epoch': 1655344800, 'time': '2022-06-16 02:00', 'temp_c': 8.6, 'temp_f': 47.5, 'is_day': 0, 'condition': {'text': 'Cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png', 'code': 1006}, 'wind_mph': 17.4, 'wind_kph': 28.1, 'wind_degree': 154, 'wind_dir': 'SSE', 'pressure_mb': 1005.0, 'pressure_in': 29.66, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 69, 'cloud': 83, 'feelslike_c': 4.9, 'feelslike_f': 40.8, 'windchill_c': 4.9, 'windchill_f': 40.8, 'heatindex_c': 8.6, 'heatindex_f': 47.5, 'dewpoint_c': 3.2, 'dewpoint_f': 37.8, 'will_it_rain': 0, 'chance_of_rain': 0, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 24.2, 'gust_kph': 38.9, 'uv': 1.0}, {'time_epoch': 1655348400, 'time': '2022-06-16 03:00', 'temp_c': 8.7, 'temp_f': 47.7, 'is_day': 0, 'condition': {'text': 'Light rain shower', 'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png', 'code': 1240}, 'wind_mph': 17.4, 'wind_kph': 28.1, 'wind_degree': 150, 'wind_dir': 'SSE', 'pressure_mb': 1005.0, 'pressure ...

# %%
for max_temp_7days in data_7days['forecast']['forecastday']:
    if max_temp_7days ['day']['maxtemp_c'] < 15:
        print("On", max_temp_7days['date'], "The highest temperature is", max_temp_7days['day']['maxtemp_c'], "C degrees and it's cold")

print ("It is always below 15C degrees and cold in Reykjavik, Iceland, because it's in the Arctic!!")
# Out:
# On 2022-06-16 The highest temperature is 11.4 C degrees and it's cold
# On 2022-06-17 The highest temperature is 11.7 C degrees and it's cold
# On 2022-06-18 The highest temperature is 11.1 C degrees and it's cold
# It is always below 15C degrees and cold in Reykjavik, Iceland, because it's in the Arctic!!

# %% [markdown]
# I changed the API to the 7 days forecast but it still shows for 3 days...

# %% [markdown]
# ## 6) What will be the hottest day in the next three days? What is the high temperature on that day?

# %%
url_3days = 'http://api.weatherapi.com/v1/forecast.json?key=976685a7f4594f9c90b191549221406&q=Reykjavik&days=3&aqi=no&alerts=no'
response_3days = requests.get(url_3days)
data_3days = response_3days.json()
print(data_3days)
# Out:
# {'location': {'name': 'Reykjavik', 'region': 'Gullbringusysla', 'country': 'Iceland', 'lat': 64.15, 'lon': -21.95, 'tz_id': 'Atlantic/Reykjavik', 'localtime_epoch': 1655410085, 'localtime': '2022-06-16 20:08'}, 'current': {'last_updated_epoch': 1655406000, 'last_updated': '2022-06-16 19:00', 'temp_c': 11.0, 'temp_f': 51.8, 'is_day': 0, 'condition': {'text': 'Light rain', 'icon': '//cdn.weatherapi.com/weather/64x64/night/296.png', 'code': 1183}, 'wind_mph': 18.6, 'wind_kph': 29.9, 'wind_degree': 140, 'wind_dir': 'SE', 'pressure_mb': 1003.0, 'pressure_in': 29.62, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 62, 'cloud': 100, 'feelslike_c': 8.0, 'feelslike_f': 46.4, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.0, 'gust_mph': 20.4, 'gust_kph': 32.8}, 'forecast': {'forecastday': [{'date': '2022-06-16', 'date_epoch': 1655337600, 'day': {'maxtemp_c': 11.4, 'maxtemp_f': 52.5, 'mintemp_c': 8.5, 'mintemp_f': 47.3, 'avgtemp_c': 10.0, 'avgtemp_f': 50.0, 'maxwind_mph': 19.5, 'maxwind_kph': 31.3, 'totalprecip_mm': 2.8, 'totalprecip_in': 0.11, 'avgvis_km': 9.9, 'avgvis_miles': 6.0, 'avghumidity': 67.0, 'daily_will_it_rain': 1, 'daily_chance_of_rain': 99, 'daily_will_it_snow': 0, 'daily_chance_of_snow': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png', 'code': 1063}, 'uv': 4.0}, 'astro': {'sunrise': '02:57 AM', 'sunset': 'No sunset', 'moonrise': '12:00 AM', 'moonset': '12:00 AM', 'moon_phase': 'Waxing Gibbous', 'moon_illumination': '78'}, 'hour': [{'time_epoch': 1655337600, 'time': '2022-06-16 00:00', 'temp_c': 8.7, 'temp_f': 47.7, 'is_day': 0, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 17.2, 'wind_kph': 27.7, 'wind_degree': 156, 'wind_dir': 'SSE', 'pressure_mb': 1005.0, 'pressure_in': 29.67, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 70, 'cloud': 53, 'feelslike_c': 5.0, 'feelslike_f': 41.0, 'windchill_c': 5.0, 'windchill_f': 41.0, 'heatindex_c': 8.7, 'heatindex_f': 47.7, 'dewpoint_c': 3.6, 'dewpoint_f': 38.5, 'will_it_rain': 0, 'chance_of_rain': 0, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 23.5, 'gust_kph': 37.8, 'uv': 1.0}, {'time_epoch': 1655341200, 'time': '2022-06-16 01:00', 'temp_c': 8.7, 'temp_f': 47.7, 'is_day': 0, 'condition': {'text': 'Patchy rain possible', 'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png', 'code': 1063}, 'wind_mph': 17.4, 'wind_kph': 28.1, 'wind_degree': 156, 'wind_dir': 'SSE', 'pressure_mb': 1005.0, 'pressure_in': 29.67, 'precip_mm': 0.1, 'precip_in': 0.0, 'humidity': 69, 'cloud': 61, 'feelslike_c': 5.0, 'feelslike_f': 41.0, 'windchill_c': 5.0, 'windchill_f': 41.0, 'heatindex_c': 8.7, 'heatindex_f': 47.7, 'dewpoint_c': 3.4, 'dewpoint_f': 38.1, 'will_it_rain': 1, 'chance_of_rain': 98, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 23.7, 'gust_kph': 38.2, 'uv': 1.0}, {'time_epoch': 1655344800, 'time': '2022-06-16 02:00', 'temp_c': 8.6, 'temp_f': 47.5, 'is_day': 0, 'condition': {'text': 'Cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png', 'code': 1006}, 'wind_mph': 17.4, 'wind_kph': 28.1, 'wind_degree': 154, 'wind_dir': 'SSE', 'pressure_mb': 1005.0, 'pressure_in': 29.66, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 69, 'cloud': 83, 'feelslike_c': 4.9, 'feelslike_f': 40.8, 'windchill_c': 4.9, 'windchill_f': 40.8, 'heatindex_c': 8.6, 'heatindex_f': 47.5, 'dewpoint_c': 3.2, 'dewpoint_f': 37.8, 'will_it_rain': 0, 'chance_of_rain': 0, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 24.2, 'gust_kph': 38.9, 'uv': 1.0}, {'time_epoch': 1655348400, 'time': '2022-06-16 03:00', 'temp_c': 8.7, 'temp_f': 47.7, 'is_day': 0, 'condition': {'text': 'Light rain shower', 'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png', 'code': 1240}, 'wind_mph': 17.4, 'wind_kph': 28.1, 'wind_degree': 150, 'wind_dir': 'SSE', 'pressure_mb': 1005.0, 'pres ...

# %%
#Example of the first day
print(data_3days['forecast']['forecastday'][0]['day']['maxtemp_c'])
print(data_3days['forecast']['forecastday'][0]['date'])
# Out:
# 11.4
# 2022-06-16

# %%
MaxTemp = max(Temp3 ["day"]["maxtemp_c"] for Temp3 in data_3days ["forecast"]["forecastday"])

for Temp3 in data_3days ["forecast"]["forecastday"]:
    if Temp3["day"]["maxtemp_c"] == MaxTemp:
        print (Temp3["date"], "has the highest temperature of", MaxTemp, "C degree,", "but it is still cold")
# Out:
# 2022-06-17 has the highest temperature of 11.7 C degree, but it is still cold

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
# - *Tip: You'll only need one day of forecast*

# %%
url_miami = 'http://api.weatherapi.com/v1/forecast.json?key=976685a7f4594f9c90b191549221406&q=Miami&days=1&aqi=no&alerts=no'
response_miami = requests.get(url_miami)
data_miami = response_miami.json()
print(data_miami)
# Out:
# {'location': {'name': 'Miami', 'region': 'Florida', 'country': 'United States of America', 'lat': 25.77, 'lon': -80.19, 'tz_id': 'America/Kentucky/Monticello', 'localtime_epoch': 1655412479, 'localtime': '2022-06-16 16:47'}, 'current': {'last_updated_epoch': 1655412300, 'last_updated': '2022-06-16 16:45', 'temp_c': 31.7, 'temp_f': 89.1, 'is_day': 1, 'condition': {'text': 'Sunny', 'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png', 'code': 1000}, 'wind_mph': 12.5, 'wind_kph': 20.2, 'wind_degree': 80, 'wind_dir': 'E', 'pressure_mb': 1018.0, 'pressure_in': 30.06, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 56, 'cloud': 0, 'feelslike_c': 36.7, 'feelslike_f': 98.0, 'vis_km': 16.0, 'vis_miles': 9.0, 'uv': 8.0, 'gust_mph': 13.4, 'gust_kph': 21.6}, 'forecast': {'forecastday': [{'date': '2022-06-16', 'date_epoch': 1655337600, 'day': {'maxtemp_c': 32.9, 'maxtemp_f': 91.2, 'mintemp_c': 28.4, 'mintemp_f': 83.1, 'avgtemp_c': 29.9, 'avgtemp_f': 85.9, 'maxwind_mph': 13.2, 'maxwind_kph': 21.2, 'totalprecip_mm': 0.1, 'totalprecip_in': 0.0, 'avgvis_km': 10.0, 'avgvis_miles': 6.0, 'avghumidity': 66.0, 'daily_will_it_rain': 0, 'daily_chance_of_rain': 0, 'daily_will_it_snow': 0, 'daily_chance_of_snow': 0, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png', 'code': 1003}, 'uv': 11.0}, 'astro': {'sunrise': '06:29 AM', 'sunset': '08:13 PM', 'moonrise': '10:57 PM', 'moonset': '08:35 AM', 'moon_phase': 'Waxing Gibbous', 'moon_illumination': '78'}, 'hour': [{'time_epoch': 1655352000, 'time': '2022-06-16 00:00', 'temp_c': 28.9, 'temp_f': 84.0, 'is_day': 0, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 12.1, 'wind_kph': 19.4, 'wind_degree': 110, 'wind_dir': 'ESE', 'pressure_mb': 1017.0, 'pressure_in': 30.04, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 69, 'cloud': 40, 'feelslike_c': 32.4, 'feelslike_f': 90.3, 'windchill_c': 28.9, 'windchill_f': 84.0, 'heatindex_c': 32.4, 'heatindex_f': 90.3, 'dewpoint_c': 22.6, 'dewpoint_f': 72.7, 'will_it_rain': 0, 'chance_of_rain': 0, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 15.4, 'gust_kph': 24.8, 'uv': 1.0}, {'time_epoch': 1655355600, 'time': '2022-06-16 01:00', 'temp_c': 28.9, 'temp_f': 84.0, 'is_day': 0, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 10.5, 'wind_kph': 16.9, 'wind_degree': 113, 'wind_dir': 'ESE', 'pressure_mb': 1017.0, 'pressure_in': 30.03, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 68, 'cloud': 43, 'feelslike_c': 32.3, 'feelslike_f': 90.1, 'windchill_c': 28.9, 'windchill_f': 84.0, 'heatindex_c': 32.3, 'heatindex_f': 90.1, 'dewpoint_c': 22.4, 'dewpoint_f': 72.3, 'will_it_rain': 0, 'chance_of_rain': 0, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 13.6, 'gust_kph': 22.0, 'uv': 1.0}, {'time_epoch': 1655359200, 'time': '2022-06-16 02:00', 'temp_c': 28.9, 'temp_f': 84.0, 'is_day': 0, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 10.7, 'wind_kph': 17.3, 'wind_degree': 113, 'wind_dir': 'ESE', 'pressure_mb': 1017.0, 'pressure_in': 30.03, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 68, 'cloud': 46, 'feelslike_c': 32.3, 'feelslike_f': 90.1, 'windchill_c': 28.9, 'windchill_f': 84.0, 'heatindex_c': 32.3, 'heatindex_f': 90.1, 'dewpoint_c': 22.4, 'dewpoint_f': 72.3, 'will_it_rain': 0, 'chance_of_rain': 0, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 14.1, 'gust_kph': 22.7, 'uv': 1.0}, {'time_epoch': 1655362800, 'time': '2022-06-16 03:00', 'temp_c': 28.8, 'temp_f': 83.8, 'is_day': 0, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 10.5, 'wind_kph': 16.9, 'wind_degree': 113, 'wind_dir': 'ESE', 'pressure_mb': 1017. ...

# %%
print(data_miami['forecast']['forecastday'][0]['hour'][0].keys())
# Out:
# dict_keys(['time_epoch', 'time', 'temp_c', 'temp_f', 'is_day', 'condition', 'wind_mph', 'wind_kph', 'wind_degree', 'wind_dir', 'pressure_mb', 'pressure_in', 'precip_mm', 'precip_in', 'humidity', 'cloud', 'feelslike_c', 'feelslike_f', 'windchill_c', 'windchill_f', 'heatindex_c', 'heatindex_f', 'dewpoint_c', 'dewpoint_f', 'will_it_rain', 'chance_of_rain', 'will_it_snow', 'chance_of_snow', 'vis_km', 'vis_miles', 'gust_mph', 'gust_kph', 'uv'])

# %%
#Example
print(data_miami['forecast']['forecastday'][0]['hour'][0]['time'])
print(data_miami['forecast']['forecastday'][0]['hour'][0]['temp_c'])
print(data_miami['forecast']['forecastday'][0]['hour'][0]['cloud'])
# Out:
# 2022-06-16 00:00
# 28.9
# 40

# %%
#Example: we just loop through the second list because it's just only one day
print(data_miami['forecast']['forecastday'][0]['hour'][1]['time'])
# Out:
# 2022-06-16 01:00

# %%
for weather_miami in data_miami['forecast']['forecastday'][0]['hour']:
    if weather_miami['cloud'] > 50:
        print ("On", weather_miami['time'], "the temperature is", weather_miami['temp_c'], "C degree", "and it's cloudy")
    else:
        print ("On", weather_miami['time'], "the temperature is", weather_miami['temp_c'], "C degree")
# Out:
# On 2022-06-16 00:00 the temperature is 28.9 C degree
# On 2022-06-16 01:00 the temperature is 28.9 C degree
# On 2022-06-16 02:00 the temperature is 28.9 C degree
# On 2022-06-16 03:00 the temperature is 28.8 C degree
# On 2022-06-16 04:00 the temperature is 28.7 C degree and it's cloudy
# On 2022-06-16 05:00 the temperature is 28.5 C degree and it's cloudy
# On 2022-06-16 06:00 the temperature is 28.4 C degree and it's cloudy
# On 2022-06-16 07:00 the temperature is 28.4 C degree and it's cloudy
# On 2022-06-16 08:00 the temperature is 28.5 C degree and it's cloudy
# On 2022-06-16 09:00 the temperature is 28.8 C degree and it's cloudy
# On 2022-06-16 10:00 the temperature is 29.1 C degree
# On 2022-06-16 11:00 the temperature is 30.7 C degree and it's cloudy
# On 2022-06-16 12:00 the temperature is 32.6 C degree
# On 2022-06-16 13:00 the temperature is 32.7 C degree
# On 2022-06-16 14:00 the temperature is 32.8 C degree
# On 2022-06-16 15:00 the temperature is 32.9 C degree
# On 2022-06-16 16:00 the temperature is 32.6 C degree
# On 2022-06-16 17:00 the temperature is 31.7 C degree
# On 2022-06-16 18:00 the temperature is 30.8 C degree
# On 2022-06-16 19:00 the temperature is 29.9 C degree
# On 2022-06-16 20:00 the temperature is 29.1 C degree
# On 2022-06-16 21:00 the temperature is 29.0 C degree and it's cloudy
# On 2022-06-16 22:00 the temperature is 28.9 C degree and it's cloudy
# On 2022-06-16 23:00 the temperature is 28.9 C degree and it's cloudy

# %% [markdown]
# ## 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %%
#Now I swtiched from C to F
#Example: I need to only loop through the second list (time)
print(data_miami['forecast']['forecastday'][0]['hour'][1]['temp_f'])
# Out:
# 84.0

# %%
#How many hours it is above 85 degree?
miami = 0
for weather_miami in data_miami['forecast']['forecastday'][0]['hour']:
    if weather_miami['temp_f'] > 85:
         miami =  miami+1
print(miami)

#How many hours in a day?
print(len(weather_miami))

warm = miami/len(weather_miami)*100

#What percent of the time is the temperature above 85 degrees?
print(f"It is {warm:.1f} percentage of the time, the temperature is above 85 degrees")
# Out:
# 9
# 33
# It is 27.3 percentage of the time, the temperature is above 85 degrees

# %% [markdown]
# ## 9) How much will it cost if you need to use 1,500,000 API calls?
#
# You are only allowed 1,000,000 API calls each month. If you were really bad at this homework or made some awful loops, WeatherAPI might shut down your free access.
#
# * *Tip: this involves looking somewhere that isn't the normal documentation.*

# %% [markdown]
# Anything above 1,000,000 calls per month isn't free, so it will be $4/month for the lowest subscription option of 2,000,000 callls per month...

# %% [markdown]
# ## 10) You're too poor to spend more money! What else could you do instead of give them money?
#
# * *Tip: I'm not endorsing being sneaky, but newsrooms and students are both generally poverty-stricken.*

# %% [markdown]
# You just make a new account with a new email address :)
